# %% [markdown]
# # Data Augmentation notebook

# %% [markdown]
# ### Waveforms sampling and data augmentation
#
# For this part, we will be using the tqdne generative model.

# %%
# !generate-waveforms

# %% [markdown]
# A way to do it, would be exploring our data to generate quakes that are in a sim

# %%
# !generate-waveforms \
  --hypocentral_distance 531 \
  --magnitude 6 \
  --vs30 154 \
  --hypocentre_depth 10.0 \
  --azimuthal_gap 130 \
  --num_samples 32 \
  --outfile test_aug_waveforms.h5 \
  --edm_checkpoint /scratch/brikiyou/ift3710/tqdne-0.2.1/tqdne/weights/edm.ckpt \
  --autoencoder_checkpoint /scratch/brikiyou/ift3710/tqdne-0.2.1/tqdne/weights/autoencoder.ckpt
# Out:
# using provided checkpoints
# using command line input data
# loading model...
# loading models...
# generating waveforms using cuda...
# 100%|█████████████████████████████████████████████| 1/1 [01:01<00:00, 61.42s/it]
# done!

# %%
from tqdne.generate_waveforms import generate

"""
@th.no_grad()
def generate(
    hypocentral_distance,
    magnitude,
    vs30,
    hypocentre_depth,
    azimuthal_gap,
    num_samples,
    csv,
    outfile,
    batch_size,
    edm_checkpoint,
    autoencoder_checkpoint,
):


"""
generate(531, 6, 154, 10.0, 130, 32, "test_aug_waveforms.h5", csv="", outfile="/scratch/brikiyou/ift3710/tqdne-0.2.1/tqdne/weights/edm.ckpt", "/scratch/brikiyou/ift3710/tqdne-0.2.1/tqdne/weights/autoencoder.ckpt" )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 4
#       1 from tqdne.generate_waveforms import generate
# ----> 4 generate(531, 6, 154, 10.0, 130, 32, "test_aug_waveforms.h5", "/scratch/brikiyou/ift3710/tqdne-0.2.1/tqdne/weights/edm.ckpt", "/scratch/brikiyou/ift3710/tqdne-0.2.1/tqdne/weights/autoencoder.ckpt" )
#
# File /scratch/brikiyou/ift3710/env/py1105/lib/python3.11/site-packages/torch/utils/_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# TypeError: generate() missing 2 required positional arguments: 'edm_checkpoint' and 'autoencoder_checkpoint'
