# %% [markdown]
# ## Waveform Prediction using SSMs (Mamba2)

# %% [markdown]
# #### 1. Data Preparation and loading
#
# to download the data, please refer to the following code:
#
#
# - loading the data from arrow file

# %% [markdown]
# #### 2. Model Definition
